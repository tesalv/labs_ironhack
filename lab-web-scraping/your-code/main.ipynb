# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here

response =  requests.get(url)
response.status_code
# Out:
# 200

# %% [markdown]
# #### 1. Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools or clicking in 'Inspect' on any browser. Here is an example:
#
# ![title](example_1.png)
#
# 2. Use BeautifulSoup `find_all()` to extract all the html elements that contain the developer names. Hint: pass in the `attrs` parameter to specify the class.
#
# 3. Loop through the elements found and get the text for each of them.
#
# 4. While you are at it, use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names. Hint: you may also use `.get_text()` instead of `.text` and pass in the desired parameters to do some string manipulation (check the documentation).
#
# 5. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
soup = BeautifulSoup(response.content)
h1 = soup.find_all("h1",attrs={"class":"h3 lh-condensed"})
[i.find("a").get("href") for i in h1]
# Out:
# ['/alex',
#  '/marten-seemann',
#  '/ijjk',
#  '/manucorporat',
#  '/willmcgugan',
#  '/bradfitz',
#  '/stefanprodan',
#  '/jordansexton',
#  '/unknwon',
#  '/SauravMukherjee44',
#  '/Dun-sin',
#  '/AskAlexSharov',
#  '/casey',
#  '/hrydgard',
#  '/slok',
#  '/amacneil',
#  '/ryanb',
#  '/JonnyBurger',
#  '/jonataslaw',
#  '/wader',
#  '/justvanrossum',
#  '/bkamins',
#  '/Jutanium',
#  '/fzyzcjy',
#  '/jlevy']

# %% [markdown]
# #### 1.1. Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
# your code here

response =  requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)
h1 = soup.find_all("h1",attrs={"class":"h3 lh-condensed"})
#articles[0].find("a").get("href")

[i.find("a").get("href") for i in h1]
# Out:
# ['/donnemartin/system-design-primer',
#  '/open-mmlab/mmrotate',
#  '/PaddlePaddle/PaddleOCR',
#  '/iperov/DeepFaceLab',
#  '/lkwq007/stablediffusion-infinity',
#  '/MatrixTM/MHDDoS',
#  '/Visualize-ML/Book4_Power-of-Matrix',
#  '/home-assistant/core',
#  '/mindsdb/mindsdb',
#  '/TheLastBen/fast-stable-diffusion',
#  '/yu-steven/openit',
#  '/LmeSzinc/AzurLaneAutoScript',
#  '/automl/TabPFN',
#  '/google-research/t5x',
#  '/pwndbg/pwndbg',
#  '/3b1b/manim',
#  '/MainSilent/DiscordAlwaysType',
#  '/RsaCtfTool/RsaCtfTool',
#  '/yaoching0/CLCNet-Rethinking-of-Ensemble-Modeling',
#  '/yt-dlp/yt-dlp',
#  '/huggingface/diffusers',
#  '/FTM-Labs/Aptos-NFT-Mint',
#  '/ytdl-org/youtube-dl',
#  '/fineanmol/Hacktoberfest2022',
#  '/octallium/modern-python-101']

# %% [markdown]
# #### 2. Display all the image links from Walt Disney wikipedia page.
# Hint: use `.get()` to access information inside tags. Check out the documentation.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here

response =  requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)
h1 = soup.find_all("a",{"class":"image"})
[i.find("img").get("src") for i in h1]
# Out:
# ['//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg/220px-Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
# ...

# %% [markdown]
# #### 2.1. List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here
response =  requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)
strong = soup.find_all("strong")

languages = [i.text for i in strong]
languages=languages[1:-1]
languages

bdi= soup.find_all("bdi",attrs={"dir":"ltr"})
articles=[i.text.replace("\xa0","") for i in bdi]
articles=articles[:10]
articles

lang_arti=list(zip(languages,articles))
lang_arti
# Out:
# [('English', '6458000+'),
#  ('日本語', '1314000+'),
#  ('Español', '1755000+'),
#  ('Русский', '1798000+'),
#  ('Français', '2400000+'),
#  ('Deutsch', '2667000+'),
#  ('Italiano', '1742000+'),
#  ('中文', '1256000+'),
#  ('Português', '1085000+'),
#  ('العربية', '1159000+')]

# %% [markdown]
# #### 2.2. Display the top 10 languages by number of native speakers stored in a pandas dataframe.
# Hint: After finding the correct table you want to analyse, you can use a nested **for** loop to find the elements row by row (check out the 'td' and 'tr' tags). <br>An easier way to do it is using pd.read_html(), check out documentation [here](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.read_html.html).

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here


response =  requests.get(url)
response.status_code

soup = BeautifulSoup(response.content)
soup
# table = soup.find_all("table",attrs={"class":"wikitable sortable static-row-numbers"}) 
table = soup.find_all("a",attrs={"class":"mw-redirect"})
languages=[i.text for i in table]
top_languages=languages[7:17]
top_languages
# Out:
# ['Mandarin Chinese',
#  'Spanish',
#  'English',
#  'Hindi',
#  'Bengali',
#  'Portuguese',
#  'Russian',
#  'Japanese',
#  'Yue Chinese',
#  'Vietnamese']

# %% [markdown]
# #### 3. Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.
# Hint: If you hover over the title of the movie, you should see the director's name. Can you find where it's stored in the html?

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here
response = requests.get(url=url)
response.status_code
soup=BeautifulSoup(response.content)
table=soup.find_all("td",attrs={"class":"titleColumn"})

movie=[i.find("a").text for i in table]
#print(movie)
direct=[i.find("a").get("title") for i in table]
#print(direct)
direct=[i.find("a").get("title") for i in table]
#print(direct)
release=[i.find("span").text for i in table]

# %%
stars_col=soup.find_all("td",attrs={"class":"ratingColumn imdbRating"})
stars=[i.find("strong").text for i in stars_col]
stars

movies_df=pd.DataFrame(list(zip(movie,release,direct,stars)),columns=["Movie","release_date","Director","rating"])
movies_df
# Out:
#                                Movie release_date  \
# 0         Os Condenados de Shawshank       (1994)
# 1                         O Padrinho       (1972)
# 2             O Cavaleiro das Trevas       (2008)
# 3               O Padrinho: Parte II       (1974)
# 4               Doze Homens em Fúria       (1957)
# ..                               ...          ...
# 245  Dersu Uzala - A Águia da Estepe       (1975)
# 246                           Gandhi       (1982)
# 247                     As Serviçais       (2011)
# 248                          Aladdin       (1992)
# 249               O Gigante de Ferro       (1999)
#
#                                               Director rating
# 0    Frank Darabont (dir.), Tim Robbins, Morgan Fre...    9.2
# 1    Francis Ford Coppola (dir.), Marlon Brando, Al...    9.2
# 2    Christopher Nolan (dir.), Christian Bale, Heat...    9.0
# 3    Francis Ford Coppola (dir.), Al Pacino, Robert...    9.0
# ...

# %% [markdown]
# #### 3.1. Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'https://www.imdb.com/list/ls009796553/'

# %%
# your code here

response = requests.get(url=url)
response.status_code
soup=BeautifulSoup(response.content)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Random Movies - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/list/ls009796553/" rel="canonical"/>
# <meta content="http://www.imdb.com/list/ls009796553/" property="og:url"/>
# ...

# %%
movies_info=soup.find_all("div",attrs={"class":"lister-item-content"})
movie_title=[i.find("a").text for i in movies_info]
movie_title
year=movies_info[3].find("span")
year
# Out:
# <span class="lister-item-index unbold text-primary">4.</span>

# %%
year=[i.find_all("span",attrs={"class":"lister-item-year text-muted unbold"})[0].text for i in movies_info]
year
# Out:
# ['(1984)',
#  '(1990)',
#  '(1992)',
#  '(1993)',
#  '(1994)',
#  '(1996)',
#  '(1997)',
#  '(1997)',
#  '(1998)',
#  '(1998)',
#  '(1999)',
#  '(2000)',
#  '(2000)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2002)',
#  '(2002)',
#  '(2002)',
#  '(2002)',
#  '(2003)',
#  '(2003)',
#  '(2003)',
#  '(2003)',
#  '(2004)',
#  '(2004)',
#  '(2004)',
#  '(2005)',
#  '(2005)',
#  '(2006)',
#  '(2007)',
#  '(2009)',
#  '(2009)',
#  '(2009)',
#  '(I) (2010)',
#  '(2010)',
#  '(2011)',
#  '(2011)',
#  '(2011 Video)',
#  '(1988)',
#  '(1990)',
#  '(1991)',
#  '(1991)',
#  '(1992)',
#  '(1992)',
#  '(1994)',
#  '(1995)',
#  '(1995)',
#  '(1995)',
#  '(1997)',
#  '(1998)',
#  '(1998)',
#  '(1999)',
#  '(2000)',
#  '(2000)',
#  '(2000)',
#  '(2000)',
#  '(2000)',
#  '(2000)',
#  '(2000)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2001)',
#  '(2002)',
#  '(2002)',
#  '(2003)',
#  '(2003)',
# ...

# %%
description=[i.find_all("p",attrs={"class":""})[0].text.strip() for i in movies_info]
description
# Out:
# ['Teenager Nancy Thompson must uncover the dark truth concealed by her parents after she and her friends become targets of the spirit of a serial killer with a bladed glove in their dreams, in which if they die, it kills them in real life.',
#  'The victims of an encephalitis epidemic many years ago have been catatonic ever since, but now a new drug offers the prospect of reviving them.',
#  'Two sisters join the first female professional baseball league and struggle to help it succeed amid their own growing rivalry.',
#  'A father becomes worried when a local gangster befriends his son in the Bronx in the 1960s.',
#  'When a boy prays for a chance to have a family if the California Angels win the pennant, angels are assigned to make that possible.',
#  'In Clanton, Mississippi, a fearless young lawyer and his assistant defend a black man accused of murdering two white men who raped his ten-year-old daughter, inciting violent retribution and revenge from the Ku Klux Klan.',
# ...

# %%
random_df=pd.DataFrame(list(zip(movie_title,year,description)),columns=["Movie","release_date","Summary"])
random_df
# Out:
#                              Movie release_date  \
# 0           Pesadelo em Elm Street       (1984)
# 1                      Despertares       (1990)
# 2                 Liga de Mulheres       (1992)
# 3         Um Bairro em Nova Iorque       (1993)
# 4                   Anjos em Campo       (1994)
# ..                             ...          ...
# 95                   Burning Palms       (2010)
# 96               Professora Baldas       (2011)
# 97  A Melhor Despedida de Solteira   (I) (2011)
# 98      Chucky, o Boneco Diabólico       (1988)
# 99       Quem Não Chora Não... Ama       (1990)
#
#                                               Summary
# 0   Teenager Nancy Thompson must uncover the dark ...
# 1   The victims of an encephalitis epidemic many y...
# 2   Two sisters join the first female professional...
# 3   A father becomes worried when a local gangster...
# 4   When a boy prays for a chance to have a family...
# ..                                                ...
# ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here

# %% [markdown]
# ####  Display the 100 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.
# ***Hint:*** Here the displayed number of earthquakes per page is 20, but you can easily move to the next page by looping through the desired number of pages and adding it to the end of the url.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/?view='

# This is how you will loop through each page:
number_of_pages = int(100/20)
each_page_urls = []

for n in range(1, number_of_pages+1):
    link = url+str(n)
    each_page_urls.append(link)
    
each_page_urls

# %%
# your code here
