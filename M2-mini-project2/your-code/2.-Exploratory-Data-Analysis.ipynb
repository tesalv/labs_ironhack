# %% [markdown]
# # Inferential statistics
# ## Part II - Exploratory Data Analysis
#
# Before starting the actual analysis it's a good idea to explore the data that we will be using, to give yourself a first idea of the questions you will be able to answer with your data, the bias you could have, other data you could need, etc.
#
# ### Libraries
# In addition to pandas we will also import matplolib and seaborn so that we will able to plot our data to better understand it.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 100)
# Out:
# c:\Users\te_sa\anaconda3\envs\ironhack\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Explore the dataset
#
# Let's load the cleaned dataset first. Import it with the name `wnba` and show the head.

# %%
#your code here

wbna=pd.read_csv("..\data\wnba_clean.csv")
wbna
# Out:
#      Unnamed: 0              Name Team  Pos  Height  Weight        BMI  \
# 0             0     Aerial Powers  DAL    F     183    71.0  21.200991
# 1             1       Alana Beard   LA  G/F     185    73.0  21.329438
# 2             2      Alex Bentley  CON    G     170    69.0  23.875433
# 3             3   Alex Montgomery  SAN  G/F     185    84.0  24.543462
# 4             4      Alexis Jones  MIN    G     175    78.0  25.469388
# ..          ...               ...  ...  ...     ...     ...        ...
# 137         138     Tiffany Hayes  ATL    G     178    70.0  22.093170
# 138         139   Tiffany Jackson   LA    F     191    84.0  23.025685
# 139         140  Tiffany Mitchell  IND    G     175    69.0  22.530612
# 140         141      Tina Charles   NY  F/C     193    84.0  22.550941
# 141         142     Yvonne Turner  PHO    G     175    59.0  19.265306
#
#     Birth_Place           Birthdate  Age         College Experience  \
# ...

# %% [markdown]
# **Use describe() to take an initial look at the data.**

# %%
#your code here
wbna.describe()
# Out:
#        Unnamed: 0      Height      Weight         BMI         Age  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000
# mean    70.859155  184.612676   78.978873   23.091214   27.112676
# std     41.536891    8.698128   10.996110    2.073691    3.667180
# min      0.000000  165.000000   55.000000   18.390675   21.000000
# 25%     35.250000  175.750000   71.500000   21.785876   24.000000
# 50%     70.500000  185.000000   79.000000   22.873314   27.000000
# 75%    106.750000  191.000000   86.000000   24.180715   30.000000
# max    142.000000  206.000000  113.000000   31.555880   36.000000
#
#        Games Played          MIN         FGM         FGA         FG%  \
# count    142.000000   142.000000  142.000000  142.000000  142.000000
# mean      24.429577   500.105634   74.401408  168.704225   43.102817
# std        7.075477   289.373393   55.980754  117.165809    9.855199
# min        2.000000    12.000000    1.000000    3.000000   16.700000
# ...

# %% [markdown]
# Most of the game-related stats have a very high range of values which can be explained by the fact that the dataset contains data on both players that play the majority of games and also players that may spend almost the entirety of the season on the bench.
#
# There are also some extremes in the weight and age columns. Feel free, if you'd like, to check which are the players with a very high (or low) age/weight and do some research on them. This is useful to confirm that they are simply outliers and not errors in the data.

# %%
#your code here
Q1_weight=wbna["Weight"].quantile(0.25)
Q3_weight=wbna["Weight"].quantile(0.75)
IQR_weight=Q3_weight-Q1_weight

Q1_age=wbna["Age"].quantile(0.25)
Q3_age=wbna["Age"].quantile(0.75)
IQR_age=Q3_age-Q1_age

IQR_weight
IQR_age

w_lower_lim=Q1_weight-1.5*IQR_weight
w_upper_lim=Q3_weight+.5*IQR_weight

a_lower_lim=Q1_age-1.5*IQR_age
a_upper_lim=Q3_age+.5*IQR_age

print(w_lower_lim,w_upper_lim)
print(a_lower_lim,a_upper_lim)
# Out:
# 49.75 93.25
# 15.0 33.0

# %%
w_outliers=wbna[(wbna["Weight"]<w_lower_lim)|(wbna["Weight"]>w_upper_lim)]
w_outliers
# Out:
#      Unnamed: 0              Name Team  Pos  Height  Weight        BMI  \
# 12           12   Amanda Zahui B.   NY    C     196   113.0  29.414827
# 23           23     Brionna Jones  CON    F     191   104.0  28.507990
# 31           31    Carolyn Swords  SEA    C     198    95.0  24.232221
# 36           36    Courtney Paris  DAL    C     193   113.0  30.336385
# 41           41    Danielle Adams  CON  F/C     185   108.0  31.555880
# 64           64   Jennifer Hamson  IND    C     201    95.0  23.514269
# 84           84  Lanay Montgomery  SEA    C     196    96.0  24.989588
# 89           89     Lynetta Kizer  CON    C     193   104.0  27.920213
# 124         125   Stefanie Dolson  CHI    C     196    97.0  25.249896
# 130         131     Sylvia Fowles  MIN    C     198    96.0  24.487297
#
#     Birth_Place           Birthdate  Age         College Experience  \
# 12           SE      August 9, 1993   24       Minnesota          3
# ...

# %%
a_outliers=wbna[(wbna["Age"]<a_lower_lim)|(wbna["Age"]>a_upper_lim)]
a_outliers
# Out:
#      Unnamed: 0              Name Team  Pos  Height  Weight        BMI  \
# 1             1       Alana Beard   LA  G/F     185    73.0  21.329438
# 30           30  Cappie Pondexter  CHI    G     175    73.0  23.836735
# 45           45     Diana Taurasi  PHO    G     183    74.0  22.096808
# 52           52    Érika de Souza  SAN    C     196    86.0  22.386506
# 67           67       Jia Perkins  MIN    G     173    75.0  25.059307
# 88           88    Lindsay Whalen  MIN    G     175    78.0  25.469388
# 94           95    Monique Currie  PHO  G/F     183    80.0  23.888441
# 105         106  Plenette Pierson  MIN  F/C     188    88.0  24.898144
# 109         110  Rebekkah Brunson  MIN    F     188    84.0  23.766410
# 126         127          Sue Bird  SEA    G     175    68.0  22.204082
#
#     Birth_Place          Birthdate  Age      College Experience  Games Played  \
# 1            US       May 14, 1982   35         Duke         12            30
# ...

# %%
all_outliers=wbna[(wbna["Weight"]<w_lower_lim)|(wbna["Weight"]>w_upper_lim)|(wbna["Age"]<a_lower_lim)|(wbna["Age"]>a_upper_lim)]
all_outliers.head()
# Out:
#     Unnamed: 0              Name Team  Pos  Height  Weight        BMI  \
# 1            1       Alana Beard   LA  G/F     185    73.0  21.329438
# 12          12   Amanda Zahui B.   NY    C     196   113.0  29.414827
# 23          23     Brionna Jones  CON    F     191   104.0  28.507990
# 30          30  Cappie Pondexter  CHI    G     175    73.0  23.836735
# 31          31    Carolyn Swords  SEA    C     198    95.0  24.232221
#
#    Birth_Place          Birthdate  Age         College Experience  \
# 1           US       May 14, 1982   35            Duke         12
# 12          SE     August 9, 1993   24       Minnesota          3
# 23          US  December 18, 1995   21        Maryland          R
# 30          US       July 1, 1983   34         Rutgers         11
# 31          US      July 19, 1989   28  Boston College          6
#
#     Games Played  MIN  FGM  FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  OREB  \
# ...

# %% [markdown]
# ### Looking at the distributions of the data
# Let's take a look at the distribution of the 4 stats that describe the physical characteristics of the players.
#
# **Plot the four distributions about `height`, `weight`, `age` and `BMI`.**

# %%
#your code here

fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,sharey=True,figsize=(20,7))
ax1.hist(wbna["Height"],bins=15)
ax2.hist(wbna["Weight"],bins=15)
ax3.hist(wbna["Age"],bins=15)
ax4.hist(wbna["BMI"],bins=15)

plt.show()

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
#your conclusions here

#the age is the biggest std and therefore more spread out graph. BMI is the one with the biggest kurtosis, meaning the players have a more similar BMI
#  that does not vary as much among the players

# %% [markdown]
# In addition to what the describe() method already told us we can see that the physical characteristics of the players (apart from the age) more or less follow a standard distribution, which is expected when looking at the distribution of values that arise from a lot of factors that are independent from each other as is the case for many physical quantities.
#
# The height distribution looks like a bimodal. This may be due to the fact that players in basketball fall under two main categories (please note that this is a very gross generalization): shorter and more agile, and taller and less agile. Therefore there are less "average" height players since they will neither be as agile as the shorter players nor have the same impact in the paint (that is, under the basket) as a taller player.
#
# The age distribution is a bit skewed to the right which is expected since most professional players stop playing after their prime physical years come to an end.

# %% [markdown]
# We could do the same for the main game stats. They are points, assists, blocks, rebounds and steals.
#
# **Now plot the distribution of the columns `REB`, `AST`, `STL`, `PTS` and `BLK` the same way you did in the last cell.**

# %%
#your code here

fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(1,5,sharey=True,figsize=(20,7))
ax1.hist(wbna["REB"],bins=15)
ax2.hist(wbna["AST"],bins=15)
ax3.hist(wbna["STL"],bins=15)
ax4.hist(wbna["PTS"],bins=15)
ax5.hist(wbna["BLK"],bins=15)


plt.show()

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
#your conclusions here
##most players haven't done many blocks or assistances. POints is the parameter more uniform among the players in comparison with the other
#parameters

# %% [markdown]
# As expected all of the above distribution are heavily skewed to the right, since most players will have very low to average stats while there will be a handful of star players whose stats peak above everyone else. It is also important to think about the fact that we are simply taking the stats as they are without considering the minutes played by each player. Even though skill plays a very important factor in determining this kind of stats we also have to consider that players that play more minutes will, on average, score more points (or blocks, assists, etc.).

# %% [markdown]
# **For the sake of it let's look at the same distributions by dividing those stats by the minutes played for each player in the dataset.**

# %%
#your code here
wbna.head()


fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(1,5,sharey=True,figsize=(20,7))
ax1.hist(wbna["REB"]/wbna["MIN"],bins=15)
ax2.hist(wbna["AST"]/wbna["MIN"],bins=15)
ax3.hist(wbna["STL"]/wbna["MIN"],bins=15)
ax4.hist(wbna["PTS"]/wbna["MIN"],bins=15)
ax5.hist(wbna["BLK"]/wbna["MIN"],bins=15)

plt.show()

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
#your conclusions here

#the shape of most of the graphs changed, excpet the blocks, and look more like a normal distribution. The skween of all graphs move more
#towards the centre of the graph and the grapsh look a bit more symetric

# %% [markdown]
# ### Summary
#
# The main insights we obtained from this exploratory analysis are:
# - Game-related stats have a very high range of values.
# - There are some extremes in the weight and age columns.
# - The physical characteristics of the players more or less follow a standard distribution.
# - We need to take into account that our dataset contains data on both players that play the majority of games and also players that may spend almost the entirety of the season on the bench.
#
# Now, it's time to try to put an end to your family's discussions. As seen on the README, the main discussions are:
# - Your grandmother says that your sister couldn't play in a professional basketball league (not only the WNBA, but ANY professional basketball league) because she's too skinny and lacks muscle.
# - Your sister says that most female professional players fail their free throws.
# - Your brother-in-law heard on the TV that the average assists among NBA (male) and WNBA (female) players is 52 for the 2016-2017 season. He is convinced this average would be higher if we only considered the players from the WNBA.
#
# **Do you think you have all the necessary data to answer these questions?**

# %%
#your comments here
#we only have data on the wnba so we can't take any conclusions on what happens in other leagues like the grandma and the brother in-law
